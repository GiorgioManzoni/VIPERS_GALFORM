# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
zCOSMOS = pd.read_csv("../data/cosmos/cesam_zcosbrightspec20k_dr3_catalog_1559644675.csv")

# %%
zCOSMOS.columns.values
# Out:
# array(['id', 'ra', 'dec', 'zpec', 'cc', 'mag_sel', 'flag_s', 'flag_x',
#        'flag_r', 'flag_uv'], dtype=object)

# %%
plt.figure(figsize=(10,8))
plt.plot(zCOSMOS['ra'][zCOSMOS['ra']>0],zCOSMOS['dec'][zCOSMOS['ra']>0],",")
plt.xlabel('RA',fontsize=30)
plt.ylabel('DEC',fontsize=30)
plt.tick_params(labelsize=15)
plt.title('zCOSMOS bright 20k DR3 z-spec',fontsize=30)
plt.ylim(1.4,3.1)
plt.xlim(149.25,151.1)
plt.savefig('../plots/018/zCOSMOS_radec.png')
plt.show()

# %%
len(zCOSMOS['ra'])
# Out:
# 20690

# %%
#pd.read_table("COSMOS2015_Laigle_v1.1.fits",)

# %%
#fits_image_filename = fits.util.get_testdata_filepath('COSMOS2015_Laigle_v1.1.fits')
hdul = fits.open('../data/cosmos/COSMOS2015_Laigle_v1.1.fits')
cat = hdul[1].data
print(cat.names) # print the names of the columns
# dir(cat) # it says which commands I can use
# Out:
# ['ALPHA_J2000', 'DELTA_J2000', 'NUMBER', 'X_IMAGE', 'Y_IMAGE', 'ERRX2_IMAGE', 'ERRY2_IMAGE', 'ERRXY_IMAGE', 'FLAG_HJMCC', 'FLUX_RADIUS', 'KRON_RADIUS', 'EBV', 'FLAG_PETER', 'FLAG_COSMOS', 'FLAG_DEEP', 'FLAG_SHALLOW', 'Ks_FLUX_APER2', 'Ks_FLUXERR_APER2', 'Ks_FLUX_APER3', 'Ks_FLUXERR_APER3', 'Ks_MAG_APER2', 'Ks_MAGERR_APER2', 'Ks_MAG_APER3', 'Ks_MAGERR_APER3', 'Ks_MAG_AUTO', 'Ks_MAGERR_AUTO', 'Ks_MAG_ISO', 'Ks_MAGERR_ISO', 'Ks_FLAGS', 'Ks_IMAFLAGS_ISO', 'Y_FLUX_APER2', 'Y_FLUXERR_APER2', 'Y_FLUX_APER3', 'Y_FLUXERR_APER3', 'Y_MAG_APER2', 'Y_MAGERR_APER2', 'Y_MAG_APER3', 'Y_MAGERR_APER3', 'Y_MAG_AUTO', 'Y_MAGERR_AUTO', 'Y_MAG_ISO', 'Y_MAGERR_ISO', 'Y_FLAGS', 'Y_IMAFLAGS_ISO', 'H_FLUX_APER2', 'H_FLUXERR_APER2', 'H_FLUX_APER3', 'H_FLUXERR_APER3', 'H_MAG_APER2', 'H_MAGERR_APER2', 'H_MAG_APER3', 'H_MAGERR_APER3', 'H_MAG_AUTO', 'H_MAGERR_AUTO', 'H_MAG_ISO', 'H_MAGERR_ISO', 'H_FLAGS', 'H_IMAFLAGS_ISO', 'J_FLUX_APER2', 'J_FLUXERR_APER2', 'J_FLUX_APER3', 'J_FLUXERR_APER3', 'J_MAG_APER2', 'J_MAGE
# ...

# %%
plt.figure(figsize=(10,8))
plt.plot(cat["ALPHA_J2000"],cat["DELTA_J2000"],",")
plt.xlabel("RA [J2000]",fontsize=30)
plt.ylabel("DEC [J2000]",fontsize=30)
plt.tick_params(labelsize=15)
plt.title("COSMOS Laigle+15 (photo-z)",fontsize=30)
plt.ylim(1.4,3.1)
plt.xlim(149.25,151.1)
plt.savefig('../plots/018/COSMOS_Laigle15_radec.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(cat["ALPHA_J2000"][cat['B_MAG_APER2']<0],cat["DELTA_J2000"][cat['B_MAG_APER2']<0],",",label='B_MAG_APER2 < 0')
#plt.SCATTER(cat["ALPHA_J2000"],cat["DELTA_J2000"])
plt.xlabel("RA [J2000]",fontsize=30)
plt.ylabel("DEC [J2000]",fontsize=30)
plt.tick_params(labelsize=15)
plt.title("COSMOS Laigle+15 (photo-z)",fontsize=30)
plt.ylim(1.4,3.1)
plt.xlim(149.25,151.1)
plt.legend(loc=1)
plt.savefig('../plots/018/COSMOS_Laigle15_bad_values_B.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(cat["ALPHA_J2000"][cat['H_MAG_APER2']<0],cat["DELTA_J2000"][cat['H_MAG_APER2']<0],",",label='H_MAG_APER2 < 0')
#plt.SCATTER(cat["ALPHA_J2000"],cat["DELTA_J2000"])
plt.xlabel("RA [J2000]",fontsize=30)
plt.ylabel("DEC [J2000]",fontsize=30)
plt.tick_params(labelsize=15)
plt.title("COSMOS Laigle+15 (photo-z)",fontsize=30)
plt.ylim(1.4,3.1)
plt.xlim(149.25,151.1)
plt.legend(loc=1)
plt.savefig('../plots/018/COSMOS_Laigle15_bad_values_H.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
#plt.plot(cat['ZPDF'][cat['B_MAG_APER2']>0],cat['B_MAG_APER2'][cat['B_MAG_APER2']>0],",")
plt.plot(cat['ZPDF'],cat['B_MAG_APER2'],",")
plt.xlim(0.,6.5)
plt.xlabel('ZPDF',fontsize=30)
plt.ylabel('B_MAG_APER2',fontsize=30)
plt.tick_params(labelsize=15)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(cat['ZPDF'][cat['B_MAG_APER2']>0],cat['B_MAG_APER2'][cat['B_MAG_APER2']>0],",")
plt.xlim(0.,6.5)
plt.xlabel('ZPDF',fontsize=30)
plt.ylabel('B_MAG_APER2',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_Laigle15_H_vs_z.png')
plt.show()

# %%
cat['NBFILT'].max()
# Out:
# 32

# %%
plt.figure(figsize=(10,8))
plt.hist(cat['NBFILT'],bins=32) # the maximum number of filters is 32
plt.xlabel("NBFILT",fontsize=25)
plt.ylabel("counts",fontsize=25)
plt.tick_params(labelsize=12)
plt.savefig('../plots/018/COSMOS_NBFILT.png')
plt.show()

# %%
len(cat['NBFILT'])
# Out:
# 1182108

# %%
plt.figure(figsize=(10,8))
plt.hist(cat['B_MAG_APER2'][cat['B_MAG_APER2']>0],bins=60,log=True)
plt.xlabel('B_MAG_APER2',fontsize=30)
plt.ylabel('log counts',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_B_histo.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(cat['B_MAG_APER2'],np.log10(cat['B_FLUX_APER2']),",")
plt.xlim(18,29)
plt.ylim(-5.,3.2)
plt.xlabel('B_MAG_APER2',fontsize=30)
plt.ylabel('B_FLUX_APER2',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_MAG_FLUX_B.png')
plt.show()
# Out:
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log10

# %%
plt.hist(cat['H_FLUX_APER2'],bins=30)#,range=(-0.4,1))
# Out:
# (array([1.180808e+06, 5.230000e+02, 2.220000e+02, 1.160000e+02,
#         7.700000e+01, 6.200000e+01, 2.800000e+01, 2.900000e+01,
#         3.200000e+01, 3.500000e+01, 2.800000e+01, 1.900000e+01,
#         1.600000e+01, 1.800000e+01, 2.900000e+01, 1.100000e+01,
#         8.000000e+00, 9.000000e+00, 6.000000e+00, 6.000000e+00,
#         6.000000e+00, 7.000000e+00, 3.000000e+00, 1.000000e+00,
#         2.000000e+00, 2.000000e+00, 2.000000e+00, 1.000000e+00,
#         0.000000e+00, 2.000000e+00]),
#  array([  -99.9    ,   998.27167,  2096.4434 ,  3194.615  ,  4292.7866 ,
#          5390.9585 ,  6489.13   ,  7587.302  ,  8685.474  ,  9783.645  ,
#         10881.816  , 11979.988  , 13078.16   , 14176.332  , 15274.503  ,
#         16372.675  , 17470.846  , 18569.018  , 19667.19   , 20765.361  ,
#         21863.533  , 22961.705  , 24059.877  , 25158.049  , 26256.22   ,
#         27354.393  , 28452.562  , 29550.734  , 30648.906  , 31747.078  ,
#         32845.25   ], dtype=float32),
# ...

# %%
plt.figure(figsize=(10,8))
plt.plot(cat['H_MAG_APER2'],np.log10(cat['H_FLUX_APER2']),",")
#plt.xlim(18,29)
#plt.ylim(-4.,3.2)
plt.xlabel('H_MAG_APER2',fontsize=30)
plt.ylabel('H_FLUX_APER2',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_MAG_FLUX_H.png')
plt.show()
# Out:
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log10

# %%
plt.figure(figsize=(10,8))
plt.hist(cat['H_MAG_APER2'][cat['H_MAG_APER2']>0.],bins=60,log=True)#,range=(-0.4,1))
#plt.xlim(15.,30.)
plt.xlabel('H_MAG_APER2',fontsize=30)
plt.ylabel('log counts',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_H_histo.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(cat['ip_MAG_APER2'][cat['ip_MAG_APER2']>0.],bins=60,log=True)#,range=(-0.4,1))
#plt.xlim(15.,30.)
plt.xlabel('ip_MAG_APER2',fontsize=30)
plt.ylabel('log counts',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_ip_histo.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(cat['H_MAG_APER2'][(cat['H_MAG_APER2']>0.)&(cat['H_MAGERR_APER2']<4000.)],
         cat['H_MAGERR_APER2'][(cat['H_MAG_APER2']>0.)&(cat['H_MAGERR_APER2']<4000.)],",")

#plt.xlim(20.,27.)
#plt.ylim(0.,1000.)

plt.xlabel('H_MAG_APER2',fontsize=30)
plt.ylabel('H_MAGERR_APER2',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_MAG_ERROR_H_nolimits.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(cat['H_MAG_APER2'][(cat['H_MAG_APER2']>0.)&(cat['H_MAG_APER2']<30.)],cat['H_MAGERR_APER2'][(cat['H_MAG_APER2']>0.)&(cat['H_MAG_APER2']<30.)],",")

plt.xlim(20.,27.)
plt.ylim(0.,1.)

selection = [(cat['H_MAG_APER2']>20.)&(cat['H_MAG_APER2']<27.)&(cat['H_MAGERR_APER2']>0)&(cat['H_MAGERR_APER2']<1.)]

plt.xlabel('H_MAG_APER2',fontsize=30)
plt.ylabel('H_MAGERR_APER2',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_MAG_ERROR_H.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
#plt.plot(cat['H_MAG_APER2'][(cat['H_MAG_APER2']>0.)&(cat['H_MAG_APER2']<30.)],cat['H_MAGERR_APER2'][(cat['H_MAG_APER2']>0.)&(cat['H_MAG_APER2']<30.)],",")
plt.plot(np.log10(cat['H_FLUX_APER2'][(cat['H_FLUXERR_APER2']>0.)]),
         cat['H_FLUXERR_APER2'][(cat['H_FLUXERR_APER2']>0.)],",")
#plt.plot(cat['H_FLUX_APER2'],cat['H_FLUXERR_APER2'],",")

plt.xlim(-4.,4.)
plt.ylim(0.02,0.25)

plt.xlabel('log H_FLUX_APER2',fontsize=30)
plt.ylabel('H_FLUXERR_APER2',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_FLUX_ERROR_H.png')
plt.show()
# Out:
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(10,8))
plt.plot(np.log10(cat['H_FLUX_APER2'][selection]),
         cat['H_FLUXERR_APER2'][selection],",")

plt.xlim(-4.,4.)
plt.ylim(0.02,0.25)

plt.xlabel('log H_FLUX_APER2',fontsize=30)
plt.ylabel('H_FLUXERR_APER2',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_FLUX_ERROR_H_selection.png')
plt.show()
# Out:
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(10,8))
#plt.plot(cat['H_MAG_APER2'][(cat['H_MAG_APER2']>0.)&(cat['H_MAG_APER2']<30.)],cat['H_MAGERR_APER2'][(cat['H_MAG_APER2']>0.)&(cat['H_MAG_APER2']<30.)],",")
plt.plot(cat['H_FLUX_APER2'][(cat['H_FLUXERR_APER2']>0.)],cat['H_FLUXERR_APER2'][(cat['H_FLUXERR_APER2']>0.)],",")


plt.xlim(0.,75.)
plt.ylim(0.,0.3)

plt.xlabel('H_FLUX_APER2',fontsize=30)
plt.ylabel('H_FLUXERR_APER2',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_FLUX_ERROR_H.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
#plt.plot(cat['H_MAG_APER2'][(cat['H_MAG_APER2']>0.)&(cat['H_MAG_APER2']<30.)],cat['H_MAGERR_APER2'][(cat['H_MAG_APER2']>0.)&(cat['H_MAG_APER2']<30.)],",")
plt.plot(np.log10(cat['H_FLUX_APER2'][(cat['H_FLUXERR_APER2']>0.)]),np.log10(cat['H_FLUXERR_APER2'][(cat['H_FLUXERR_APER2']>0.)]),",")


#plt.xlim(0.,75.)
#plt.ylim(0.,0.3)

plt.xlabel('log H_FLUX_APER2',fontsize=30)
plt.ylabel('log H_FLUXERR_APER2',fontsize=30)
plt.tick_params(labelsize=15)
plt.savefig('../plots/018/COSMOS_log_FLUX_ERROR_H.png')
plt.show()
# Out:
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.plot(cat['H_FLUXERR_APER2'][selection],cat['H_MAGERR_APER2'][selection],",")
#plt.ylim(0.,0.3)
#plt.xlim(0.,0.2)
plt.show()
# Out:
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(cat['r_FLUXERR_APER2'][(cat['r_MAG_APER2']>20.)&(cat['r_MAG_APER2']<25.)],cat['r_MAGERR_APER2'][(cat['r_MAG_APER2']>20.)&(cat['r_MAG_APER2']<25.)],",")
plt.ylim(0.,0.3)
plt.xlim(0.,0.2)
# Out:
# (0.0, 0.2)

# %%
plt.scatter(cat['r_FLUXERR_APER3'][(cat['r_MAG_APER2']>20.)&(cat['r_MAG_APER2']<25.)],
            cat['r_MAGERR_APER3'][(cat['r_MAG_APER2']>20.)&(cat['r_MAG_APER2']<25.)],",")
            #c=cat['r_MAG_APER3'][(cat['r_MAG_APER2']>20.)&(cat['r_MAG_APER2']<25.)])
plt.ylim(0.,0.3)
plt.xlim(0.,0.2)
#plt.colorbar()
# Out:
# (0.0, 0.2)

# %%
selection = [(cat['H_MAG_APER2']>20.)&(cat['H_MAG_APER2']<27.)&(cat['H_MAGERR_APER2']>0)&(cat['H_MAGERR_APER2']<1.)]

plt.figure(figsize=(10,8))

plt.plot(cat['r_FLUXERR_APER2'][selection],
         cat['r_MAGERR_APER2'][selection],",")
plt.ylim(0.,0.6)
plt.xlim(0.,0.2)

plt.xlabel('r_FLUXERR_APER2',fontsize=30)
plt.ylabel('r_MAGERR_APER2',fontsize=30)

plt.tick_params(labelsize=15)

plt.savefig('../plots/018/COSMOS_FLUXERR_vs_MAGERR_r.png')

plt.show()
# Out:
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   """
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
selection = [(cat['H_MAG_APER2']>20.)&(cat['H_MAG_APER2']<27.)&(cat['H_MAGERR_APER2']>0)&(cat['H_MAGERR_APER2']<1.)]

plt.figure(figsize=(10,8))

plt.plot(cat['H_FLUXERR_APER2'][selection],
         cat['H_MAGERR_APER2'][selection],",")
#plt.ylim(0.,0.6)
plt.xlim(0.,0.4)

plt.xlabel('H_FLUXERR_APER2',fontsize=30)
plt.ylabel('H_MAGERR_APER2',fontsize=30)

plt.tick_params(labelsize=15)

plt.savefig('../plots/018/COSMOS_FLUXERR_vs_MAGERR_H.png')

plt.show()
# Out:
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   """
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
selection = [(cat['H_MAG_APER2']>20.)&(cat['H_MAG_APER2']<27.)&(cat['H_MAGERR_APER2']>0)&(cat['H_MAGERR_APER2']<1.)]

plt.figure(figsize=(10,8))

plt.plot(cat['H_FLUXERR_APER2'],
         cat['H_MAGERR_APER2'],",")
plt.ylim(0.,2.)
plt.xlim(0.,0.4)

plt.xlabel('H_FLUXERR_APER2',fontsize=30)
plt.ylabel('H_MAGERR_APER2',fontsize=30)

plt.tick_params(labelsize=15)

plt.show()

# %%
plt.hist(cat['r_MAG_AUTO'][cat['r_MAG_AUTO']<80],bins=30,range=(17,35))
# Out:
# (array([2.04000e+02, 2.98000e+02, 8.27000e+02, 1.78100e+03, 3.11800e+03,
#         5.00900e+03, 7.47300e+03, 1.07420e+04, 1.60350e+04, 2.46820e+04,
#         3.87990e+04, 6.24720e+04, 9.68080e+04, 1.36851e+05, 1.69836e+05,
#         1.72197e+05, 1.17534e+05, 6.24240e+04, 3.30550e+04, 1.82690e+04,
#         1.03920e+04, 5.88200e+03, 3.24500e+03, 1.93700e+03, 1.02300e+03,
#         6.38000e+02, 3.59000e+02, 2.28000e+02, 1.27000e+02, 8.10000e+01]),
#  array([17. , 17.6, 18.2, 18.8, 19.4, 20. , 20.6, 21.2, 21.8, 22.4, 23. ,
#         23.6, 24.2, 24.8, 25.4, 26. , 26.6, 27.2, 27.8, 28.4, 29. , 29.6,
#         30.2, 30.8, 31.4, 32. , 32.6, 33.2, 33.8, 34.4, 35. ],
#        dtype=float32),
#  <a list of 30 Patch objects>)

# %%
plt.figure(figsize=(10,8))
plt.plot(cat['r_MAG_AUTO'],cat['r_FLUX_APER2'],",")
plt.ylim(0,75)
plt.xlim(15,30)
plt.xlabel('r_MAG_AUTO',fontsize=30)
plt.ylabel('r_FLUX_APER2',fontsize=30)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(cat['r_MAG_APER2'],cat['r_MAG_AUTO'],",")
plt.xlim(15,30)
plt.ylim(15,40)
plt.xlabel('r_MAG_APER2',fontsize=30)
plt.ylabel('r_MAG_AUTO',fontsize=30)
plt.plot([1.,100.],[1.,100.],c='k',ls='--')
plt.axvline(25.,c='k',ls='--')
plt.axhline(25.,c='k',ls='--')
plt.savefig('../plots/018/COSMOS_MAG_APER2_vs_AUTO_r.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(cat['r_FLUX_APER2'],cat['r_FLUX_APER3'],",")
plt.ylim(-1,100)
plt.xlim(-1,100)
plt.xlabel('r_FLUX_APER2',fontsize=30)
plt.ylabel('r_FLUX_APER3',fontsize=30)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(cat['r_MAG_APER2'],cat['r_MAG_ISO'],",")
plt.ylim(15,40)
plt.xlim(15,30)
plt.plot([1.,100.],[1.,100.],c='k',ls='--')
plt.axvline(25.,c='k',ls='--')
plt.axhline(25.,c='k',ls='--')
plt.xlabel('r_MAG_APER2',fontsize=30)
plt.ylabel('r_MAG_ISO',fontsize=30)
plt.savefig('../plots/018/COSMOS_MAG_APER2_vs_ISO_r.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(cat['r_MAG_AUTO'],cat['r_MAG_ISO'],",")
plt.ylim(15,35)
plt.xlim(15,35)
plt.plot([1.,100.],[1.,100.],c='k',ls='--')
plt.axvline(25.,c='k',ls='--')
plt.axhline(25.,c='k',ls='--')
plt.xlabel('r_MAG_AUTO',fontsize=30)
plt.ylabel('r_MAG_ISO',fontsize=30)
plt.savefig('../plots/018/COSMOS_MAG_AUTO_vs_ISO_r.png')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(cat['r_MAG_APER2'],cat['H_MAG_APER2'],",")
plt.ylim(15,35)
plt.xlim(15,35)
plt.plot([1.,100.],[1.,100.],c='k',ls='--')
plt.axvline(25.,c='k',ls='--')
plt.axhline(25.,c='k',ls='--')
plt.xlabel('r_MAG_APER2',fontsize=30)
plt.ylabel('H_MAG_APER2',fontsize=30)
plt.savefig('../plots/018/COSMOS_MAG_AUTO_r_vs_H.png')
plt.show()

# %%
plt.hist(cat['FLUX_RADIUS'],bins=30,range=(0.,40.))
#plt.xlim(-2.5,0)
print(np.median(cat['FLUX_RADIUS']))
plt.xlabel("FLUX_RADIUS")
plt.show()
# Out:
# 3.9206498

# %%
s= np.where((cat['H_MAG_APER2']<25.)&(cat['H_MAG_APER2']>0.)) 

plt.figure(figsize=(10,8))
plt.plot(cat['ZPDF'][s],cat['ZMINCHI2'][s],",")
plt.xlim(-0.5,6.1)
plt.ylim(-0.5,6.1)
plt.plot([-10.,100.],[-10.,100.],c='k',ls='--')
plt.xlabel("ZPDF",fontsize=30)
plt.ylabel("ZMINCHI2",fontsize=30)
plt.savefig('../plots/018/COSMOS_ZPDF_ZMINCHI2_25.png')
plt.show()
print len(s[0])
# Out:
# 391068

# %%
#s= [cat['H_MAG_APER2']<25.]
s= np.where((cat['H_MAG_APER2']<25.)&(cat['H_MAG_APER2']>0.)) 

plt.figure(figsize=(10,8))
plt.plot(np.log10(cat['H_FLUX_APER2'][s]),
         cat['H_FLUXERR_APER2'][s],",")

plt.xlim(-0.5,3.)
plt.ylim(0.05,0.25)

plt.xlabel('log H_FLUX_APER2',fontsize=30)
plt.ylabel('H_FLUXERR_APER2',fontsize=30)
plt.tick_params(labelsize=15)
plt.title('cut at H < 25',fontsize=30)
#plt.savefig('../plots/018/COSMOS_FLUX_ERROR_H_25.png')
plt.show()

# %%
#s= [cat['H_MAG_APER2']<25.]
s= np.where((cat['H_MAG_APER2']<25.)&(cat['H_MAG_APER2']>0.)) 

plt.figure(figsize=(10,8))

plt.plot(cat['H_FLUXERR_APER2'][s],
         cat['H_MAGERR_APER2'][s],",")
plt.ylim(0.,0.6)
plt.xlim(0.01,0.3)

plt.xlabel('H_FLUXERR_APER2',fontsize=30)
plt.ylabel('H_MAGERR_APER2',fontsize=30)

plt.tick_params(labelsize=15)

plt.title('cut at H < 25',fontsize=30)

#plt.savefig('../plots/018/COSMOS_FLUXERR_vs_MAGERR_H_25.png')

plt.show()

# %%
plt.figure(figsize=(10,8))

s = [(cat['H_MAG_APER2']>0.)&(cat['r_MAG_APER2']>0.)]

plt.plot(cat['H_MAG_APER2'][s],
         cat['r_MAG_APER2'][s],",")
plt.ylim(18.,28.1)
plt.xlim(15.,33.)

plt.xlabel('H_MAG_APER2',fontsize=30)
plt.ylabel('r_MAG_APER2',fontsize=30)

plt.tick_params(labelsize=15)

plt.axvline(25.,c='k',ls='--')
plt.axhline(25.,c='k',ls='--')
plt.plot([-10.,100.],[-10.,100.],c='k',ls='--')


#plt.title('cut at H < 25',fontsize=30)

plt.savefig('../plots/018/COSMOS_MAG_r_vs_H.png')

plt.show()
# Out:
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   """
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %% [markdown]
# # Write in a txt file

# %%
# __________MAG_APER2

#B V r ip zpp IB427 IB464 IA484 IB505 IA527 IB574 IA624 IA679 IA738 IA767 IB709 IB827 NB711 NB816
# yHSC
# Y,J,H,Ks
# Hw
# Ksw

#___________MAG
# SPLASH_1
# SPLASH_2
# SPLASH_3
# SPLASH_4


sel = np.where((cat['H_MAG_APER2']>0.)&(cat['H_MAG_APER2']<25.))

#the byteswap thing is needed to convert little endian to big endian (or the other way round)
#otherwise I can't use DataFrame.fillna()

carlton = pd.DataFrame(data={'NUMBER':             np.array(cat['NUMBER'            ][sel]).byteswap().newbyteorder(),
                        'ALPHA_J2000':             np.array(cat['ALPHA_J2000'       ][sel]).byteswap().newbyteorder(),
                        'DELTA_J2000':             np.array(cat['DELTA_J2000'       ][sel]).byteswap().newbyteorder(),
                        'Z_MINCHI2':               np.array(cat['ZMINCHI2'          ][sel]).byteswap().newbyteorder(),
                        'NBFILT':                  np.array(cat['NBFILT'            ][sel]).byteswap().newbyteorder(), 
                        'B_MAG_APER2':             np.array(cat['B_MAG_APER2'       ][sel]).byteswap().newbyteorder(), 
                        'B_MAGERR_APER2':          np.array(cat['B_MAGERR_APER2'    ][sel]).byteswap().newbyteorder(), 
                        'V_MAG_APER2':             np.array(cat['V_MAG_APER2'       ][sel]).byteswap().newbyteorder(),
                        'V_MAGERR_APER2':          np.array(cat['V_MAGERR_APER2'    ][sel]).byteswap().newbyteorder(),
                        'r_MAG_APER2':             np.array(cat['B_MAG_APER2'       ][sel]).byteswap().newbyteorder(),
                        'r_MAGERR_APER2':          np.array(cat['B_MAGERR_APER2'    ][sel]).byteswap().newbyteorder(),
                        'ip_MAG_APER2':            np.array(cat['ip_MAG_APER2'      ][sel]).byteswap().newbyteorder(), 
                        'ip_MAGERR_APER2':         np.array(cat['ip_MAGERR_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'zpp_MAG_APER2':           np.array(cat['zpp_MAG_APER2'     ][sel]).byteswap().newbyteorder(), 
                        'zpp_MAGERR_APER2':        np.array(cat['zpp_MAGERR_APER2'  ][sel]).byteswap().newbyteorder(), 
                        'IB427_MAG_APER2':         np.array(cat['B_MAG_APER2'       ][sel]).byteswap().newbyteorder(), 
                        'IB427_MAGERR_APER2':      np.array(cat['B_MAGERR_APER2'    ][sel]).byteswap().newbyteorder(), 
                        'IB464_MAG_APER2':         np.array(cat['IB464_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'IB464_MAGERR_APER2':      np.array(cat['IB464_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'IA484_MAG_APER2':         np.array(cat['IA484_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'IA484_MAGERR_APER2':      np.array(cat['IA484_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'IB505_MAG_APER2':         np.array(cat['IB505_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'IB505_MAGERR_APER2':      np.array(cat['IB505_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'IA527_MAG_APER2':         np.array(cat['IA527_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'IA527_MAGERR_APER2':      np.array(cat['IA527_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'IB574_MAG_APER2':         np.array(cat['IB574_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'IB574_MAGERR_APER2':      np.array(cat['IB574_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'IA624_MAG_APER2':         np.array(cat['IA624_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'IA624_MAGERR_APER2':      np.array(cat['IA624_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'IA679_MAG_APER2':         np.array(cat['IA679_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'IA679_MAGERR_APER2':      np.array(cat['IA679_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'IA738_MAG_APER2':         np.array(cat['IA738_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'IA738_MAGERR_APER2':      np.array(cat['IA738_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'IA767_MAG_APER2':         np.array(cat['IA767_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'IA767_MAGERR_APER2':      np.array(cat['IA767_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'IB709_MAG_APER2':         np.array(cat['IB709_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'IB709_MAGERR_APER2':      np.array(cat['IB709_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'IB827_MAG_APER2':         np.array(cat['IB827_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'IB827_MAGERR_APER2':      np.array(cat['IB827_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'NB711_MAG_APER2':         np.array(cat['NB711_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'NB711_MAGERR_APER2':      np.array(cat['NB711_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'NB816_MAG_APER2':         np.array(cat['NB816_MAG_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'NB816_MAGERR_APER2':      np.array(cat['NB816_MAGERR_APER2'][sel]).byteswap().newbyteorder(), 
                        'yHSC_MAG_APER2':          np.array(cat['yHSC_MAG_APER2'    ][sel]).byteswap().newbyteorder(), 
                        'yHSC_MAGERR_APER2':       np.array(cat['yHSC_MAGERR_APER2' ][sel]).byteswap().newbyteorder(), 
                        'Y_MAG_APER2':             np.array(cat['Y_MAG_APER2'       ][sel]).byteswap().newbyteorder(),
                        'Y_MAGERR_APER2':          np.array(cat['Y_MAGERR_APER2'    ][sel]).byteswap().newbyteorder(),
                        'J_MAG_APER2':             np.array(cat['J_MAG_APER2'       ][sel]).byteswap().newbyteorder(), 
                        'J_MAGERR_APER2':          np.array(cat['J_MAGERR_APER2'    ][sel]).byteswap().newbyteorder(), 
                        'H_MAG_APER2':             np.array(cat['H_MAG_APER2'       ][sel]).byteswap().newbyteorder(), 
                        'H_MAGERR_APER2':          np.array(cat['H_MAGERR_APER2'    ][sel]).byteswap().newbyteorder(), 
                        'Ks_MAG_APER2':            np.array(cat['Ks_MAG_APER2'      ][sel]).byteswap().newbyteorder(), 
                        'Ks_MAGERR_APER2':         np.array(cat['Ks_MAGERR_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'Hw_MAG_APER2':            np.array(cat['Hw_MAG_APER2'      ][sel]).byteswap().newbyteorder(), 
                        'Hw_MAGERR_APER2':         np.array(cat['Hw_MAGERR_APER2'   ][sel]).byteswap().newbyteorder(), 
                        'Ksw_MAG_APER2':           np.array(cat['Ksw_MAG_APER2'     ][sel]).byteswap().newbyteorder(), 
                        'Ksw_MAGERR_APER2':        np.array(cat['Ksw_MAGERR_APER2'  ][sel]).byteswap().newbyteorder(), 
                        'SPLASH_1_MAG':            np.array(cat['SPLASH_1_MAG'      ][sel]).byteswap().newbyteorder(), 
                        'SPLASH_1_MAGERR':         np.array(cat['SPLASH_1_MAGERR'   ][sel]).byteswap().newbyteorder(), 
                        'SPLASH_2_MAG':            np.array(cat['SPLASH_2_MAG'      ][sel]).byteswap().newbyteorder(), 
                        'SPLASH_2_MAGERR':         np.array(cat['SPLASH_2_MAGERR'   ][sel]).byteswap().newbyteorder(), 
                        'SPLASH_3_MAG':            np.array(cat['SPLASH_3_MAG'      ][sel]).byteswap().newbyteorder(), 
                        'SPLASH_3_MAGERR':         np.array(cat['SPLASH_3_MAGERR'   ][sel]).byteswap().newbyteorder(), 
                        'SPLASH_4_MAG':            np.array(cat['SPLASH_4_MAG'      ][sel]).byteswap().newbyteorder(),
                        'SPLASH_4_MAGERR':         np.array(cat['SPLASH_4_MAGERR'   ][sel]).byteswap().newbyteorder() })

carlton = carlton.fillna(value=-99.)

# %%
carlton
# Out:
#         ALPHA_J2000  B_MAGERR_APER2  B_MAG_APER2  DELTA_J2000  H_MAGERR_APER2  \
# 0        149.383456       -1.000000    27.984539     1.592311        5.584501
# 1        149.381972       -1.000000    27.982168     1.593225        1.272462
# 2        149.364830        0.084999    24.645685     1.593214        0.386468
# 3        149.376466       -1.000000    27.564135     1.593090        1.226921
# 4        149.384518       -1.000000    27.981575     1.595381        1.880376
# 5        149.384259        0.301991    27.153414     1.596558        1.716300
# 6        149.362320       -1.000000    26.868910     1.596878        0.055236
# 7        149.382306       -1.000000    27.990475     1.597793        0.681798
# 8        149.381147       -1.000000    27.988949     1.599328        0.587258
# 9        149.361196        0.049895    23.933224     1.597846        0.108796
# 10       149.360542        0.066120    24.310551     1.599474        0.099340
# ...

# %%
len(carlton)
# Out:
# 391068

# %%
carlton.to_csv('../data/cosmos/laigle15_cut_H25_with_err.txt',index=None,sep=',')

# %%
# !ls ../data/cosmos/
# Out:
# COSMOS2015_Laigle_header.txt
# COSMOS2015_Laigle_v1.1.fits
# COSMOS2015_Laigle_v1.1.fits.gz
# Neural_network.ipynb
# REALLY_READ_THIS_FIRST.txt
# Varenna.ipynb
# cesam_zcosbrightspec20k_dr3_catalog_1559644675.csv
# laigle15_cut_H25.csv
# laigle15_cut_H25.txt
# laigle15_cut_H25_with_err.txt
# loss_function_example.png
# loss_function_example_1.png
# loss_function_example_correct.png
# match_COSMOS.txt
# match_COSMOS_999.txt

# %%
pd.read_csv("../data/cosmos/laigle15_cut_H25_with_err.txt",delimiter=',')
# Out:
#         ALPHA_J2000  B_MAGERR_APER2  B_MAG_APER2  DELTA_J2000  H_MAGERR_APER2  \
# 0        149.383456       -1.000000    27.984539     1.592311        5.584501
# 1        149.381972       -1.000000    27.982168     1.593225        1.272462
# 2        149.364830        0.084999    24.645685     1.593214        0.386468
# 3        149.376466       -1.000000    27.564135     1.593090        1.226921
# 4        149.384518       -1.000000    27.981575     1.595381        1.880376
# 5        149.384259        0.301991    27.153414     1.596558        1.716300
# 6        149.362320       -1.000000    26.868910     1.596878        0.055236
# 7        149.382306       -1.000000    27.990475     1.597793        0.681798
# 8        149.381147       -1.000000    27.988949     1.599328        0.587258
# 9        149.361196        0.049895    23.933224     1.597846        0.108796
# 10       149.360542        0.066120    24.310550     1.599474        0.099340
# ...

# %%
match_cosmos = pd.read_csv("../data/cosmos/match_COSMOS_with_err.txt",delimiter=',')

# %%
match_cosmos
# Out:
#         ALPHA_J2000  B_MAGERR_APER2  B_MAG_APER2  DELTA_J2000  H_MAGERR_APER2  \
# 0        149.383456       -1.000000    27.984539     1.592311        5.584501
# 1        149.381972       -1.000000    27.982168     1.593225        1.272462
# 2        149.364830        0.084999    24.645685     1.593214        0.386468
# 3        149.376466       -1.000000    27.564135     1.593090        1.226921
# 4        149.384518       -1.000000    27.981575     1.595381        1.880376
# 5        149.384259        0.301991    27.153414     1.596558        1.716300
# 6        149.362320       -1.000000    26.868910     1.596878        0.055236
# 7        149.382306       -1.000000    27.990475     1.597793        0.681798
# 8        149.381147       -1.000000    27.988949     1.599328        0.587258
# 9        149.361196        0.049895    23.933224     1.597846        0.108796
# 10       149.360542        0.066120    24.310550     1.599474        0.099340
# ...

# %%
match_cosmos = match_cosmos.fillna(-99.)

# %%
match_cosmos
# Out:
#         ALPHA_J2000  B_MAGERR_APER2  B_MAG_APER2  DELTA_J2000  H_MAGERR_APER2  \
# 0        149.383456       -1.000000    27.984539     1.592311        5.584501
# 1        149.381972       -1.000000    27.982168     1.593225        1.272462
# 2        149.364830        0.084999    24.645685     1.593214        0.386468
# 3        149.376466       -1.000000    27.564135     1.593090        1.226921
# 4        149.384518       -1.000000    27.981575     1.595381        1.880376
# 5        149.384259        0.301991    27.153414     1.596558        1.716300
# 6        149.362320       -1.000000    26.868910     1.596878        0.055236
# 7        149.382306       -1.000000    27.990475     1.597793        0.681798
# 8        149.381147       -1.000000    27.988949     1.599328        0.587258
# 9        149.361196        0.049895    23.933224     1.597846        0.108796
# 10       149.360542        0.066120    24.310550     1.599474        0.099340
# ...

# %%
match_cosmos.to_csv('../data/cosmos/match_COSMOS_99_with_err.csv',index=None,sep=',')

# %%
pd.read_csv("../data/cosmos/match_COSMOS_99_with_err.csv",delimiter=',')
# Out:
#         ALPHA_J2000  B_MAGERR_APER2  B_MAG_APER2  DELTA_J2000  H_MAGERR_APER2  \
# 0        149.383456       -1.000000    27.984539     1.592311        5.584501
# 1        149.381972       -1.000000    27.982168     1.593225        1.272462
# 2        149.364830        0.084999    24.645685     1.593214        0.386468
# 3        149.376466       -1.000000    27.564135     1.593090        1.226921
# 4        149.384518       -1.000000    27.981575     1.595381        1.880376
# 5        149.384259        0.301991    27.153414     1.596558        1.716300
# 6        149.362320       -1.000000    26.868910     1.596878        0.055236
# 7        149.382306       -1.000000    27.990475     1.597793        0.681798
# 8        149.381147       -1.000000    27.988949     1.599328        0.587258
# 9        149.361196        0.049895    23.933224     1.597846        0.108796
# 10       149.360542        0.066120    24.310550     1.599474        0.099340
# ...
